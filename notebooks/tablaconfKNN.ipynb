# %%
import pandas as pd
import os

RESULTS_DIR = "../results"
os.makedirs(RESULTS_DIR, exist_ok=True)

tabla = pd.DataFrame({
    'Dataset':              ['GSE125449', 'GSE166635', 'ICB_HCC'],
    'N_celulas':            [9946, 25189, 3252],
    'Confianza_media_KNN':  [0.939, 0.952, 0.898],
    'Separacion_clusters':  ['Muy buena', 'Muy buena', 'Buena'],
    'Confianza_visual':     ['Mayoria amarillo', 'Casi todo amarillo', 'Mas variabilidad'],
    'Valoracion_general':   ['Excelente', 'Excelente', 'Buena'],
})

ruta = os.path.join(RESULTS_DIR, "tabla_resumen_KNN.xlsx")
tabla.to_excel(ruta, index=False)

print(f'Guardado en {ruta}')
# Out:
# Guardado en ../results/tabla_resumen_KNN.xlsx
